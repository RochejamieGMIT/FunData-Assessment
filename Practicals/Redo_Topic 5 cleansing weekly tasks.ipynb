# %% [markdown]
# # Cleansing Exercise 1
#
#
# Write a Python function to remove all non-alphanumeric characters from a string.

# %%
import re
#Create test string with mix of characters
test = '__abCD01.,eFg34lfjde()jdje=-+!"£$asdqwertQWERTY1234%^&*QWERTY'
#Create raw string for regular expression, any charatcer that is not/complement of (^) a-zA-Z0-9, 
# Not using the \W version expression as it includes _ 
REGEX1 =  r'[^a-zA-Z0-9]'
# sub nothing where non alpha numeric charaters show up 
test = re.sub(REGEX1, '',test); 
test
# Out:
# 'abCD01eFg34lfjdejdjeasdqwertQWERTY1234QWERTY'

# %% [markdown]
# # Cleansing Excercise 2
# Exercise 2
# Remember to do these exercises in your own notebook in your assessment repository.
#
# Adapt the above code to capitalise the first letter of the iris species, using regular expressions.

# %%
import requests
import urllib.request # import urllib.request
#https://www.geeksforgeeks.org/capitalize-first-letter-of-a-column-in-pandas-dataframe/?ref=rp
#https://favtutor.com/blogs/capitalize-first-letter-python

url = r'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

iris = [line.decode('utf-8').strip() for line in urllib.request.urlopen(url)] # decode iris


strip_iris = re.compile(r'([0-9]\.[0-9]),([0-9]\.[0-9]),([0-9]\.[0-9]),([0-9]\.[0-9]),Iris-([a-z])([a-z]+)')
#reiris = [strip_iris.sub(r'\5\6,\4,\3,\2,\1', line) for line in iris if line] 
#reiris[0] = reiris[0].capitalize() #Only capitalises one line
#print(reiris) 

#adding .capitalize() directly to the reg ex line works, I don't think this is the best way to do it, but I can not figure
#out an alternitive yet. 
[strip_iris.sub(r'\5\6,\4,\3,\2,\1', line).capitalize() for line in iris if line]
# Out:
# ['Setosa,0.2,1.4,3.5,5.1',
#  'Setosa,0.2,1.4,3.0,4.9',
#  'Setosa,0.2,1.3,3.2,4.7',
#  'Setosa,0.2,1.5,3.1,4.6',
#  'Setosa,0.2,1.4,3.6,5.0',
#  'Setosa,0.4,1.7,3.9,5.4',
#  'Setosa,0.3,1.4,3.4,4.6',
#  'Setosa,0.2,1.5,3.4,5.0',
#  'Setosa,0.2,1.4,2.9,4.4',
#  'Setosa,0.1,1.5,3.1,4.9',
#  'Setosa,0.2,1.5,3.7,5.4',
#  'Setosa,0.2,1.6,3.4,4.8',
#  'Setosa,0.1,1.4,3.0,4.8',
#  'Setosa,0.1,1.1,3.0,4.3',
#  'Setosa,0.2,1.2,4.0,5.8',
#  'Setosa,0.4,1.5,4.4,5.7',
#  'Setosa,0.4,1.3,3.9,5.4',
#  'Setosa,0.3,1.4,3.5,5.1',
#  'Setosa,0.3,1.7,3.8,5.7',
#  'Setosa,0.3,1.5,3.8,5.1',
#  'Setosa,0.2,1.7,3.4,5.4',
#  'Setosa,0.4,1.5,3.7,5.1',
#  'Setosa,0.2,1.0,3.6,4.6',
#  'Setosa,0.5,1.7,3.3,5.1',
#  'Setosa,0.2,1.9,3.4,4.8',
#  'Setosa,0.2,1.6,3.0,5.0',
#  'Setosa,0.4,1.6,3.4,5.0',
#  'Setosa,0.2,1.5,3.5,5.2',
#  'Setosa,0.2,1.4,3.4,5.2',
#  'Setosa,0.2,1.6,3.2,4.7',
#  'Setosa,0.2,1.6,3.1,4.8',
#  'Setosa,0.4,1.5,3.4,5.4',
#  'Setosa,0.1,1.5,4.1,5.2',
#  'Setosa,0.2,1.4,4.2,5.5',
# ...
